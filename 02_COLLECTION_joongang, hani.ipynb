# %% [markdown]
# # SETUP

# %%
import numpy as np
import pandas as pd
import requests
from scrapy.http import TextResponse
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

import time

# %% [markdown]
# ### 중앙일보

# %%
# get selenium driver
driver = webdriver.Chrome()

# make article dataframe
joongangilbo = pd.DataFrame(columns=["date", "title", "body"])
joongangilbo.tail()
# Out:
# Empty DataFrame
# Columns: [date, title, body]
# Index: []

# %%
for j in range(1, 70):
    url = "https://search.joins.com/TotalNews?page=" + str(j) + "&Keyword=%EC%82%AC%EC%84%A4%20%EB%B0%95%EA%B7%BC%ED%98%9C&PeriodType=DirectInput&StartSearchDate=12%2F20%2F2012%2000%3A00%3A00&EndSearchDate=03%2F10%2F2017%2000%3A00%3A00&SortType=New&SourceGroupType=Joongang&ServiceCode=20&SearchCategoryType=TotalNews&MatchKeyword=%EC%82%AC%EC%84%A4"
    driver.get(url)
    time.sleep(3)

    # Get current window/tab ID
    current_window = driver.current_window_handle
    
    for i in range(10):
        # .Get into Article
        articles = driver.find_elements_by_css_selector("#content > div.section_news > div.bd > ul > li")
        articles[i].find_element_by_css_selector("div > strong > a").click()

        # Get new window/tab ID
        new_window = [window for window in driver.window_handles if window != current_window][0]
        # Switch to new window/tab
        driver.switch_to.window(new_window)
        time.sleep(1)

        # .Get article data
        article_date = driver.find_element_by_css_selector("#body > div.article_head > div.clearfx > div.byline > em:nth-child(2)").text[3:13]
        article_title = driver.find_element_by_css_selector("#article_title").text
        article_body = driver.find_element_by_css_selector("#article_body").text

        joongangilbo.loc[len(joongangilbo)] = {
            "date" : article_date,
            "title" : article_title,
            "body" : article_body,
        }

        time.sleep(1)

        # Close new window/tab
        driver.close()

        # Switch to initial window/tab
        driver.switch_to.window(current_window)
        time.sleep(2)

# %%
for j in range(70, 134):
    url = "https://search.joins.com/TotalNews?page=" + str(j) + "&Keyword=%EC%82%AC%EC%84%A4%20%EB%B0%95%EA%B7%BC%ED%98%9C&PeriodType=DirectInput&StartSearchDate=12%2F20%2F2012%2000%3A00%3A00&EndSearchDate=03%2F10%2F2017%2000%3A00%3A00&SortType=New&SourceGroupType=Joongang&ServiceCode=20&SearchCategoryType=TotalNews&MatchKeyword=%EC%82%AC%EC%84%A4"
    driver.get(url)
    time.sleep(3)

    # Get current window/tab ID
    current_window = driver.current_window_handle
    
    for i in range(10):
        # .Get into Article
        articles = driver.find_elements_by_css_selector("#content > div.section_news > div.bd > ul > li")
        articles[i].find_element_by_css_selector("div > strong > a").click()

        # Get new window/tab ID
        new_window = [window for window in driver.window_handles if window != current_window][0]
        # Switch to new window/tab
        driver.switch_to.window(new_window)
        time.sleep(1)

        # .Get article data
        article_date = driver.find_element_by_css_selector("#body > div.article_head > div.clearfx > div.byline > em:nth-child(2)").text[3:13]
        article_title = driver.find_element_by_css_selector("#article_title").text
        article_body = driver.find_element_by_css_selector("#article_body").text

        joongangilbo.loc[len(joongangilbo)] = {
            "date" : article_date,
            "title" : article_title,
            "body" : article_body,
        }

        time.sleep(1)

        # Close new window/tab
        driver.close()

        # Switch to initial window/tab
        driver.switch_to.window(current_window)
        time.sleep(2)

# %%
for j in range(134, 135):
    url = "https://search.joins.com/TotalNews?page=" + str(j) + "&Keyword=%EC%82%AC%EC%84%A4%20%EB%B0%95%EA%B7%BC%ED%98%9C&PeriodType=DirectInput&StartSearchDate=12%2F20%2F2012%2000%3A00%3A00&EndSearchDate=03%2F10%2F2017%2000%3A00%3A00&SortType=New&SourceGroupType=Joongang&ServiceCode=20&SearchCategoryType=TotalNews&MatchKeyword=%EC%82%AC%EC%84%A4"
    driver.get(url)
    time.sleep(3)

    # Get current window/tab ID
    current_window = driver.current_window_handle
    
    for i in range(4):
        # .Get into Article
        articles = driver.find_elements_by_css_selector("#content > div.section_news > div.bd > ul > li")
        articles[i].find_element_by_css_selector("div > strong > a").click()

        # Get new window/tab ID
        new_window = [window for window in driver.window_handles if window != current_window][0]
        # Switch to new window/tab
        driver.switch_to.window(new_window)
        time.sleep(1)

        # .Get article data
        article_date = driver.find_element_by_css_selector("#body > div.article_head > div.clearfx > div.byline > em:nth-child(2)").text[3:13]
        article_title = driver.find_element_by_css_selector("#article_title").text
        article_body = driver.find_element_by_css_selector("#article_body").text

        joongangilbo.loc[len(joongangilbo)] = {
            "date" : article_date,
            "title" : article_title,
            "body" : article_body,
        }

        time.sleep(1)

        # Close new window/tab
        driver.close()

        # Switch to initial window/tab
        driver.switch_to.window(current_window)
        time.sleep(2)

# %%
joongangilbo.tail()
# Out:
#             date                            title  \
# 1329  2012.12.24    [사설] 박근혜·시진핑·아베, 과거 아닌 미래를 보라
# 1330  2012.12.22         [사설] 내년 예산안을 누더기로 만들 것인가
# 1331  2012.12.22          [사설] 제2, 제3의 이학재 나와야 한다
# 1332  2012.12.21        [사설] 취임까지 67일이 5년 성패 좌우한다
# 1333  2012.12.20  [사설] 여성 대통령 박근혜 … 화려한 기록, 무거운 짐
#
#                                                    body
# 1329  역사는 사람이 만든다. 사람이 만드는 역사에서 리더의 역할은 결정적이다. 지금 동북...
# 1330  치열한 대선이 끝났다. 이제 정신을 차리고 발밑의 현실을 살펴야 할 때다. 국회가 ...
# 1331  박근혜 대통령 당선인의 핵심 측근인 이학재 새누리당 의원이 어제 백의종군을 선언했다...
# 1332  박근혜 대통령 당선인이 어제 국민의 다양한 의견을 수렴하겠다고 약속했다. 또 “모든...
# 1333  박근혜 새누리당 후보가 18대 대통령으로 선출됐다. 여성 대통령은 한국은 물론 세계...

# %%
joongangilbo.to_pickle('ja_whole.pkl')

# %%
# Quit Webdriver
driver.quit()

# %% [markdown]
# ### 조선일보

# %%
# get selenium driver
driver = webdriver.Chrome()
driver.maximize_window() ## For maximizing window
driver.implicitly_wait(20) ## gives an implicit wait for 20 seconds

# make article dataframe
chosun = pd.DataFrame(columns=["date", "title", "body"])
chosun.tail()
# Out:
# Empty DataFrame
# Columns: [date, title, body]
# Index: []

# %%
# ~123page + 2

# %%
for j in range(123, 124):
    url = "http://search.chosun.com/search/news.search?query=%EC%82%AC%EC%84%A4+%EB%B0%95%EA%B7%BC%ED%98%9C&pageno=" + str(j) + "&orderby=old&naviarraystr=&kind=&cont1=%EC%82%AC%EC%84%A4&cont2=&cont5=&categoryname=&categoryd2=&c_scope=paging&sdate=2012.12.20&edate=2017.03.10&premium="
    driver.get(url)

    # Get current window/tab ID
    current_window = driver.current_window_handle
    
    for i in range(2, 3):
        # .Get into Article
        articles = driver.find_elements_by_css_selector("body > div.schCont > div > div.l_area > div.search_news_box > dl")
        articles[i].find_element_by_css_selector("dl > dt > a").click()

        # Get new window/tab ID
        new_window = [window for window in driver.window_handles if window != current_window][0]

        # Switch to new window/tab
        driver.switch_to.window(new_window)
        time.sleep(1)

        try:
            article_date = driver.find_element_by_css_selector("#news_body_id > div.news_date").text[3:13]
            article_title = driver.find_element_by_css_selector("#news_title_text_id").text
            article_body = driver.find_element_by_css_selector("#news_body_id > div.par").text

            chosun.loc[len(chosun)] = {
                "date" : article_date,
                "title" : article_title,
                "body" : article_body,
            }

            time.sleep(1)

        except:
            print("Error! in {} page, {} article".format(j, i))

        # Close new window/tab
        driver.close()

        # Switch to initial window/tab
        driver.switch_to.window(current_window)
        time.sleep(2)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-64-3f395e822369> in <module>()
#       9         # .Get into Article
#      10         articles = driver.find_elements_by_css_selector("body > div.schCont > div > div.l_area > div.search_news_box > dl")
# ---> 11         articles[i].find_element_by_css_selector("dl > dt > a").click()
#      12
#      13         # Get new window/tab ID
#
# IndexError: list index out of range

# %%
chosun.to_pickle("chosun_raw2.pkl")

# %%
chosun
# Out:
#             date                                              title  \
# 0     2012.12.20                [사설] 박근혜 당선인, 겸허하게 온 국민 껴안는 걸로 시작하라
# 1     2012.12.20                [사설] 선거 여론조사, '公表 금지 기간' 없애거나 더 단축을
# 2     2012.12.20                       [사설] 한국 진보 左派, 進化하지 않으면 몰락한다
# 3     2012.12.21                      [사설] 政權 인수, 소리 내지 말고 실무적으로 하라
# 4     2012.12.21           [사설] '5060世代 지혜' 못지않게 '2030 氣 살리기'도 중요하다
# 5     2012.12.21                     [사설] 朴 당선인, 먼저 '경제 回生' 문제 붙들어야
# 6     2012.12.23                       [사설] 개인 생산성 높여 노동력 고령화 벽 넘어야
# 7     2012.12.23                         [사설] 大탕평, 핵심 권력기관장 人事에 달렸다
# 8     2012.12.24          [사설] 민주, 1469만 지지층 목소리 반영 위해 예산 심의 적극 임하라
# 9     2012.12.24                  [사설] 人事, 보안도 중요하지만 인재 찾는 데 더 집중해야
# 10    2012.12.25              [사설] 가구 소득 470만원 느는 사이 전셋값 1778만원 뛰었다
# 11    2012.12.25                    [사설] 朴 당선인, 누구와 어떻게 무엇을 상의하고 있나
# 12    2012.12.26                 [사설] 私조직 덜 기댄 당선인, 공기업 人事 바로잡을 기회다
# 13    2012.12.27                [사설] 인수委, 당선인의 지역 통합·세대 화합 약속 뒷받침하라
# 14    2012.12.28                  [사설] 닥쳐오는 外交·安保 위기, 역대 最强팀으로 대처하라
# 15    2012.12.30                   [사설] 예산 절감 계획도 없이 '稅金 청구서'부터 내미나
# 16    2012.12.30                              [사설] 組閣도 '밀봉 인사' 할 건가
# 17    2012.12.31                  “오바마, 남북대화모색하는 박근혜당선인 도와야” NYT 사설
# 18    2012.12.31                                NYT, 글로벌호크 한국 판매 비판
# 19    2012.12.31                            NYT, 글로벌호크의 한국 판매 계획 비판
# 20    2012.12.31                                 [사설] 도전하고 시험받는 한 해
# 21    2013.01.01  北 김정은, 김일성 이후 19년만에 육성 신년사…"침략자들 선불질하면 무자비하게 격...
# 22    2013.01.01                       [사설] "남북 대결 상태 해소" 북한 하기에 달려
# 23    2013.01.01                [사설] 극빈층 3% 진료비, 상위 30% 보육비에 밀려 깎였다
# 24    2013.01.02                                "김정은 신년사, 근래 가장 온건"
